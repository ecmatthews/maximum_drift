# %%
import maximum_drift

# %%
## HD13789
t = maximum_drift.binary('example_csvs/hd13789.csv')
t.calc_m2()
t.plot_drift([2.57,0.75])
# Out:
# abs_mag >  11.928901646928832
# on-sky separation: 2.79"
# projected separation: 64 AU
# mass at host distance: 0.1901572581220165 solMass
# color-mass range: nan-nan
# companion status unknown
# observed drift: 2.57+/-0.75

# %%
##HD20010
t = maximum_drift.binary('example_csvs/hd20010.csv')
t.calc_m2()
t.plot_drift([11.28,0.26])
# Out:
# abs_mag >  5.903637850959597
# on-sky separation: 5.33"
# projected separation: 75 AU
# mass at host distance: 0.8120391512476112 solMass
# color-mass range: 0.69-1.14
# this companion is bound! (matching plx)
# observed drift: 11.28+/-0.26

# %%
##HD178340
t = maximum_drift.binary('example_csvs/hd178340.csv')
t.calc_m2()
t.plot_drift([4.43,0.16])
# Out:
# abs_mag >  15.161193062747051
# abs_mag >  16.776023062747054
# on-sky separation: 14.73"
# projected separation: 720 AU
# mass at host distance: 0.075 solMass
# color-mass range: 0.56-0.83
# companion *not* bound based on BP RP
# observed drift: 4.43+/-0.16
# on-sky separation: 10.49"
# projected separation: 513 AU
# mass at host distance: 0.08816169557188729 solMass
# color-mass range: 0.74-1.45
# companion *not* bound based on BP RP
# observed drift: 4.43+/-0.16
# on-sky separation: 14.94"
# projected separation: 731 AU
# mass at host distance: 0.07641325645750982 solMass
# color-mass range: 1.49-10.00
# companion *not* bound based on BP RP
# observed drift: 4.43+/-0.16
